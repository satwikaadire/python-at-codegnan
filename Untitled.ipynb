# %%
Name="satwika"
Age="20"
City="Hyderabad"
Career_goal="software engineering"
print("Name=",Name)
print("Age=",Age)
print("city=",City)
print("career_goal=",Career_goal)
# Out:
# Name= satwika
# Age= 20
# city= Hyderabad
# career_goal= software engineering

# %%
stdname="satwika"
clgname="Vjit"
branch="cse"
career_goal="software engineering"
print("Student Name=",stdname)
print("College Name=",clgname)
print("Branch=",branch)
print("Career Goal=",career_goal)
# Out:
# Student Name= satwika
# College Name= Vjit
# Branch= cse
# Career Goal= software engineering

# %%
print("09:00AM-Python")
print("11:00AM-Aptitude")
print("02:00PM-Soft Skills")
print("04:00PM-Practice Session")
# Out:
# 09:00AM-Python
# 11:00AM-Aptitude
# 02:00PM-Soft Skills
# 04:00PM-Practice Session
